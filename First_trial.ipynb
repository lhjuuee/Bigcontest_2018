# %%
import pandas as pd
import numpy as np

# %%
train_activity = pd.read_csv('C:/Bigcontest/train_activity.csv')

# %%
train_activity.head(10)
# Out:
#    wk                                             acc_id  cnt_dt  play_time  \
# 0   7  3dc6f2875dc6e6f35b9e2bdb25b391a8003386ff23becd...       4   2.088814
# 1   8  3dc6f2875dc6e6f35b9e2bdb25b391a8003386ff23becd...       5   2.673460
# 2   3  b8856358ff62e596fa07e3e40b8e7fd4b7729263c72b44...       2  -0.649522
# 3   4  b8856358ff62e596fa07e3e40b8e7fd4b7729263c72b44...       2  -0.658235
# 4   5  b8856358ff62e596fa07e3e40b8e7fd4b7729263c72b44...       4  -0.654734
# 5   7  b8856358ff62e596fa07e3e40b8e7fd4b7729263c72b44...       2  -0.659304
# 6   8  b8856358ff62e596fa07e3e40b8e7fd4b7729263c72b44...       5  -0.655505
# 7   8  fa883ca7505082114c4024052354f1fb416f6bae26ed06...       6  -0.658186
# 8   8  d094b6b1c5d0a147eaae3e37b256894def52de39c6eca3...       3   0.606285
# 9   1  38e7088d64485baba2968be8ad56f5b8abeced8ccd95f1...       6  -0.020100
#
#     npc_exp  npc_hongmun  quest_exp  quest_hongmun  item_hongmun  \
# 0  4.405057    -0.245477   4.454059       3.009797     -0.306354
# ...

# %%
train_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440323 entries, 0 to 440322
# Data columns (total 38 columns):
# wk                          440323 non-null int64
# acc_id                      440323 non-null object
# cnt_dt                      440323 non-null int64
# play_time                   440323 non-null float64
# npc_exp                     440323 non-null float64
# npc_hongmun                 440323 non-null float64
# quest_exp                   440323 non-null float64
# quest_hongmun               440323 non-null float64
# item_hongmun                440323 non-null float64
# game_combat_time            440323 non-null float64
# get_money                   440323 non-null float64
# duel_cnt                    440323 non-null float64
# duel_win                    440323 non-null float64
# partybattle_cnt             440323 non-null float64
# partybattle_win             440323 non-null float64
# cnt_enter_inzone_solo       440323 non-null float64
# ...

# %%
groupby_train_activity = train_activity.groupby('acc_id').median()
groupby_train_activity.head(10)
# Out:
#                                                      wk  cnt_dt  play_time  \
# acc_id
# 0000264b01392acfde44f9d8494f112a701dc5d3e5fda6a...  7.5     6.0   3.627488
# 0001f130e89288ff0df167b998f6eb7085687f411fcb724...  4.5     3.0  -0.660881
# 00028f0ad71c07f48aef465fd0c98ba6e3f0f3de3d2f7d1...  5.0     2.0  -0.659313
# 00036e5b6a197c196fa10fc0ad4e2853b22294dff64d273...  5.0     6.0  -0.575530
# 00037fe8e712041a476b8b1b827583cbc34895844057f03...  5.0     1.5  -0.655214
# 0003b127aa1c0c34490db8817574482464aad9f99cffde4...  4.5     5.0  -0.592749
# 0004733c4175d61e67d1ec9d3602f6c3341180800bc8bf2...  8.0     5.0  -0.658839
# 00047f6584e6bcfed540e1bc53651c0c27f02c5bc530919...  7.0     5.0  -0.655753
# 0004a2a2f32479b2e0ff35b2a3b9d77f9949a1d2f3f16c3...  7.0     3.0  -0.652494
# 0006502148dc2533ef4ac4b9939ee19f18483a7c3c7256f...  4.5     6.5   0.825951
#
#                                                      npc_exp  npc_hongmun  \
# acc_id
# ...
